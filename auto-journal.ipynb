# %%
import argparse
import json
import csv
import sys
import gspread
import pprint
from time import sleep
from lib import bitmex
from settings import API_KEY, API_SECRET, API_BASE
from oauth2client.service_account import ServiceAccountCredentials

# %%
pp = pprint.PrettyPrinter(indent=4)

# Connecting to spreadsheet
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('secret.json', scope)
client = gspread.authorize(creds)

# Create connector to BitMEX
connector = bitmex.BitMEX(base_url=API_BASE, apiKey=API_KEY, apiSecret=API_SECRET)

# Do trade history query
count = 2  # max API will allow is 500
query = {
    'reverse': 'true',
    'count': count
}

# %%
pos = []
position = connector._curl_bitmex(path="position", verb="GET", timeout=10)
pos.extend(position)
pp.pprint(pos)
# Out:
# [   {   'account': 1403044,
#         'avgCostPrice': 210.65,
#         'avgEntryPrice': 210.65,
#         'bankruptPrice': 223.85,
#         'breakEvenPrice': 210.5,
#         'commission': 0.00075,
#         'crossMargin': True,
#         'currency': 'XBt',
#         'currentComm': 750448,
#         'currentCost': -168580100,
#         'currentQty': -8000,
#         'currentTimestamp': '2020-05-24T10:10:30.385Z',
#         'deleveragePercentile': 1,
#         'execBuyCost': 0,
#         'execBuyQty': 0,
#         'execComm': 0,
#         'execCost': 0,
#         'execQty': 0,
#         'execSellCost': 0,
#         'execSellQty': 0,
#         'foreignNotional': 15601.857010213556,
#         'grossExecCost': 0,
#         'grossOpenCost': 0,
#         'grossOpenPremium': 0,
#         'homeNotional': -74.28040854224699,
#         'indicativeTax': 0,
#         'indicativeTaxRate': None,
#         'initMargin': 0,
#         'initMarginReq': 0.02,
#         'isOpen': True,
#         'lastPrice': 210.04,
#         'lastValue': -168032000,
#         'leverage': 50,
#         'liquidationPrice': 222.15,
#         'longBankrupt': 0,
#         'maintMargin': 3987318,
#         'maintMarginReq': 0.007999999999999998,
#         'marginCallPrice': 222.15,
#         'markPrice': 210.04,
#         'markValue': -168032000,
#         'openOrderBuyCost': 0,
#         'openOrderBuyPremium': 0,
#         'openOrderBuyQty': 0,
#         'openOrderSellCost': 0,
#         'openOrderSellPremium': 0,
#         'openOrderSellQty': 0,
#         'openingComm': 750448,
#         'openingCost': -168580100,
#         'openingQty': -8000,
#         'openingTimestamp': '2020-05-24T10:00:00.000Z',
#         'posAllowance': 0,
#         'posComm': 128918,
#         'posCost': -168520000,
#         'posCost2': -168520000,
#         'posCross': 0,
#         'posInit': 3370400,
#         'posLoss': 0,
#         'posMaint': 1477078,
#         'posMargin': 3499318,
#         'posState': '',
#         'prevClosePrice': 209.93,
#         'prevRealisedPnl': -2724677,
#         'prevUnrealisedPnl': 0,
#         'quoteCurrency': 'USD',
#         'realisedCost': -60100,
#         'realisedGrossPnl': 60100,
#         'realisedPnl': -690348,
#         'realisedTax': 0,
#         'rebalancedPnl': 576598,
#         'riskLimit': 5000000000,
#         'riskValue': 168032000,
#         'sessionMargin': 0,
#         'shortBankrupt': 0,
#         'simpleCost': None,
#         'simplePnl': None,
#         'simplePnlPcnt': None,
#         'simpleQty': None,
#         'simpleValue': None,
#         'symbol': 'ETHUSD',
#         'targetExcessMargin': 0,
#         'taxBase': 0,
#         'taxableMargin': 0,
#         'timestamp': '2020-05-24T10:10:30.385Z',
#         'underlying': 'ETH',
#         'unrealisedCost': -168520000,
#         'unrealisedGrossPnl': 488000,
#         'unrealisedPnl': 488000,
#         'unrealisedPnlPcnt': 0.0029,
#         'unrealisedRoePcnt': 0.1448,
#         'unrealisedTax': 0,
#         'varMargin': 0},
#     {   'account': 1403044,
#         'avgCostPrice': None,
#         'avgEntryPrice': None,
#         'bankruptPrice': None,
#         'breakEvenPrice': None,
#         'commission': 0.00075,
#         'crossMargin': True,
#         'currency': 'XBt',
#         'currentComm': -28863,
#         'currentCost': 840000,
#         'currentQty': 0,
#         'currentTimestamp': '2020-05-24T10:00:01.508Z',
#         'deleveragePercentile': None,
#         'execBuyCost': 0,
#         'execBuyQty': 0,
#         'execComm': 0,
#         'execCost': 0,
#         'execQty': 0,
#         'execSellCost': 0,
#         'execSellQty': 0,
#         'foreignNotional': 0,
#         'grossExecCost': 0,
#         'grossOpenCost': 0,
#         'grossOpenPremium': 0,
#         'homeNotional': 0,
#         'indicativeTax': 0,
#         'indicativeTaxRate': None,
#         'initMargin': 0,
#         'initMarginReq': 0.01,
#         'isOpen': False,
#         'lastPrice': None,
#         'lastValue': 0,
#         'leverage': 100,
#         'liquidationPrice': None,
#         'longBankrupt': 0,
#         'maintMargin': 0,
#         'maintMarginReq': 0.003999999999999999,
#         'marginCallPrice': None,
#         'markPrice': None,
#         'markValue': 0,
#         'openOrderBuyCost': 0,
#         'openOrderBuyPremium': 0,
#         'openOrderBuyQty': 0,
#         'openOrderSellCost': 0,
#         'openOrderSellPremium': 0,
#         'openOrderSellQty': 0,
#         'openingComm': -28863,
#         'openingCost': 840000,
#         'openingQty': 0,
#         'openingTimestamp': '2020-05-24T10:00:00.000Z',
#         'posAllowance': 0,
#         'posComm': 0,
#         'posCost': 0,
#         'posCost2': 0,
#         'posCross': 0,
#         'posInit': 0,
#         'posLoss': 0,
#         'posMaint': 0,
#         'posMargin': 0,
#         'posState': '',
#         'prevClosePrice': 9183.31,
#         'prevRealisedPnl': -884745,
#         'prevUnrealisedPnl': 0,
#         'quoteCurrency': 'USD',
#         'realisedCost': 840000,
#         'realisedGrossPnl': -840000,
#         'realisedPnl': -811137,
#         'realisedTax': 0,
#         'rebalancedPnl': 811137,
#         'riskLimit': 20000000000,
#         'riskValue': 0,
#         'sessionMargin': 0,
#         'shortBankrupt': 0,
#         'simpleCost': None,
#         'simplePnl': None,
#         'simplePnlPcnt': None,
#         'simpleQty': None,
#         'simpleValue': None,
#         'symbol': 'XBTUSD',
#         'targetExcessMargin': 0,
#         'taxBase': 0,
#         'taxableMargin': 0,
#         'timestamp': '2020-05-24T10:00:01.508Z',
#         'underlying': 'XBT',
#         'unrealisedCost': 0,
#         'unrealisedGrossPnl': 0,
#         'unrealisedPnl': 0,
#         'unrealisedPnlPcnt': 0,
#         'unrealisedRoePcnt': 0,
#         'unrealisedTax': 0,
#         'varMargin': 0}]
